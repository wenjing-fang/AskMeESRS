# %%
import json

# %%
with open("../scraped_text/esrs_streamed.json", "r", encoding="utf-8") as f:
    scraped_text = json.load(f)

# Now `data` is a Python list of dictionaries
print(type(scraped_text))       # <class 'list'>
print(scraped_text[0])          # First item
# Out:
# <class 'list'>
# {'class_type_id': 'a_0', 'item_num': 'ANNEX I to Commission Delegated Regulation (EU) 2023/2772 supplementing Directive', 'item_content': '2013/34/EU of the European Parliament and of the Council as regards sustainability reporting standards, published in the Official Journal of the European Union on 22 December 2023 and including the corrigendum published on 18 April 2024. European sustainability reporting standards (ESRS)'}

# %%
chapter_names = [
    "ESRS 1",
    "ESRS 2",
    "ESRS E1",
    "ESRS E2",
    "ESRS E3",
    "ESRS E4",
    "ESRS E5",
    "ESRS S1",
    "ESRS S2",
    "ESRS S3",
    "ESRS S4",
    "ESRS G1",
    "Acronyms",
    "Defined Terms"
]

# %%
for item in scraped_text:
    if item.get('subsection_title') in chapter_names:
        print(item)
    if 'section_num' in item:
        print(item)
# Out:
# {'class_type_id': 'p_d1e134-3-1', 'subsection_num': '', 'subsection_title': 'ESRS 1'}
# {'class_type_id': 'p_d1e500-3-1', 'section_num': '1.', 'section_title': 'Categories of ESRS Standards, reporting areas and drafting conventions'}
# {'class_type_id': 'p_d1e898-3-1', 'section_num': '2.', 'section_title': 'Qualitative characteristics of information'}
# {'class_type_id': 'p_d1e935-3-1', 'section_num': '3.', 'section_title': 'Double materiality as the basis for sustainability disclosures'}
# {'class_type_id': 'p_d1e1746-3-1', 'section_num': '4.', 'section_title': 'Due diligence'}
# {'class_type_id': 'p_d1e1985-3-1', 'section_num': '5.', 'section_title': 'Value chain'}
# {'class_type_id': 'p_d1e2216-3-1', 'section_num': '6.', 'section_title': 'Time horizons'}
# {'class_type_id': 'p_d1e2387-3-1', 'section_num': '7.', 'section_title': 'Preparation and presentation of sustainability information'}
# {'class_type_id': 'p_d1e2837-3-1', 'section_num': '8.', 'section_title': 'Structure of the sustainability statement'}
# {'class_type_id': 'p_d1e2978-3-1', 'section_num': '9.', 'section_title': 'Linkages with other parts of corporate reporting and connected information'}
# {'class_type_id': 'p_d1e5302-3-1', 'subsection_num': '', 'subsection_title': 'ESRS 2'}
# {'class_type_id': 'p_d1e5617-3-1', 'section_num': '1.', 'section_title': 'Basis for preparation'}
# {'class_type_id': 'p_d1e6047-3-1', 'section_num': '2.', 'section_title': 'Governance'}
# {'class_type_id': 'p_d1e6567-3-1', 'section_num': '3.', 'section_title': 'Strategy'}
# {'class_type_id': 'p_d1e7221-3-1', 'section_num': '4.', 'section_title': 'Impact, risk and opportunity management'}
# {'class_type_id': 'p_d1e7869-3-1', 'section_num': '5.', 'section_title': 'Metrics and targets'}
# {'class_type_id': 'p_d1e10096-3-1', 'subsection_num': '', 'subsection_title': 'ESRS E1'}
# {'class_type_id': 'p_d1e16555-3-1', 'subsection_num': '', 'subsection_title': 'ESRS E2'}
# {'class_type_id': 'p_d1e18729-3-1', 'subsection_num': '', 'subsection_title': 'ESRS E3'}
# {'class_type_id': 'p_d1e20709-3-1', 'subsection_num': '', 'subsection_title': 'ESRS E4'}
# {'class_type_id': 'p_d1e24283-3-1', 'subsection_num': '', 'subsection_title': 'ESRS E5'}
# {'class_type_id': 'p_d1e26395-3-1', 'subsection_num': '', 'subsection_title': 'ESRS S1'}
# {'class_type_id': 'p_d1e32497-3-1', 'subsection_num': '', 'subsection_title': 'ESRS S2'}
# {'class_type_id': 'p_d1e34825-3-1', 'subsection_num': '', 'subsection_title': 'ESRS S3'}
# {'class_type_id': 'p_d1e36958-3-1', 'subsection_num': '', 'subsection_title': 'ESRS S4'}
# {'class_type_id': 'p_d1e39162-3-1', 'subsection_num': '', 'subsection_title': 'ESRS G1'}
# {'class_type_id': 'p_', 'section_num': 'For gas-related activities, the NACE code\n definition addresses activities with direct GHG emissions that are \nhigher than 270\xa0gCO2/KWh.', 'section_title': ''}
